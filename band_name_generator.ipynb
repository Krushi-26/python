# %%
print('Hello world')
# Out:
# Hello world

# %%
print("2. Knead the dough for 10 minutes.")
# this is just to print a individuL line
# Out:
# 2. Knead the dough for 10 minutes.

# %% [markdown]
# ##Strings

# %%
print('Hello world\nhello world ')
#/n create  a new line 
print('Hello world\nhello world\nhello world')
# Out:
# Hello world
# hello world
# Hello world
# hello world
# hello world

# %%
# i can combine two strings by using + 
#  if we want space between the strings there are three ways

# %%
print('Hello world' + 'hello world ')
print('Hello world' + ' ' +'hello world ')
print('Hello world ' + 'hello world ')
# Out:
# Hello worldhello world
# Hello world hello world
# Hello world hello world

# %%
# case two to ask questions 
# we use 'input' function

# %%
input('what is your name?')
# Out:
# what is your name? krushi
# 'krushi'

# %%
#if we want to give print and input statement at the sametime 
# we use string concatenation 
#just add print and input funcation

# %%
print('Hello world' + ' ' +input('what is your name?'))
# Out:
# what is your name? k
# Hello world k

# %%
print('Hello world ' + input('what is your name? ') + "gm")
# Out:
# what is your name?  k
# Hello world kgm

# %%
# variables

# %%
# so here what i am doing is i am giving a particualr variable for a input lets say
name = input('what is your name?')
# so we can use this 'name' whereever we want and it gives the print statement
print(name)
# Out:
# what is your name? krushi
# krushi

# %%
name = 'krushi' 
print(name)
# Out:
# krushi

# %%
name = 'kru'
print(name)
# Out:
# kru

# %%
# We have 2 variables glass1 and glass2. glass1 contains milk and glass2 contains juice.
#Write 3 lines of code to switch the contents of the variables. 
# You are not allowed to type the words #"milk" or "juice". 
#You are only allowed to use variables to solve this exercise
glass1 = "milk"
glass2 = "juice"
x = glass1
glass1 = glass2
glass2 = x
# Out:
# x

# %%
# We have 2 variables glass1 and glass2. glass1 contains milk and glass2 contains juice.
#Write 3 lines of code to switch the contents of the variables. 
# You are not allowed to type the words #"milk" or "juice". 
#You are only allowed to use variables to solve this exercise
glass1 = "milk"
glass2 = "juice"
x = glass1
glass1 = glass2
glass2 = x
# Out:
# x

# %%
#Create a greeting for your program 
print('Hello!')
#ask for the city and store it in a variable 
city = input('what is the city you were born')
#ask the pet name 
pet_name = input('name of your pet')
print('Hello!'+ ' ' +city+ ' ' + pet_name)
# Out:
# Hello!
# what is the city you were born h
# name of your pet k
# Hello! h k
