# %% [markdown]
# CONDITIONAL IF/ELSE
#
# if condition:
#     do this
# else:
#     do this

# %%
print("Welcome to the class")
age = int(input("what is your age"))
if age >= 20:
    print("you can attend the class")
else:
    print("underage")
# Out:
# Welcome to the class
# what is your age 24
# you can attend the class

# %%
# check weather the given number is even or odd

number = int(input("enter the number to find even or odd"))
if number % 2 == 0:
    print("its a even number")
else:
    print("its a odd number")
# Out:
# enter the number to find even or odd 25
# its a odd number

# %% [markdown]
#
# ### if condition:
#     if another condition:
#         do this
#     else: do this
# ### else: do this

# %%
#
print("Welcome to the class")
age = int(input("what is your age"))
if age >= 20:
    print("you can attend the class")
    
    course = input("what is your class?")
    
    if course == "sql":
        print("classes done")
    else:
        if course == "python":
            print("welcome to new class")
else:
    print("underage")
# Out:
# Welcome to the class
# what is your age 20
# you can attend the class
# what is your class? python
# welcome to new class

# %%
#elif
print("Welcome to the class")
age = int(input("what is your age"))
if age >= 20:
    print("you can attend the class")
    
    course = input("what is your class?")
    
    if course == "sql":
        print("classes done")
    elif course == "python":
        print("welcome to new class")
    elif course == "sleep":
        print("happy class")    
else:
    print("underage")
# Out:
# Welcome to the class
# what is your age 20
# you can attend the class
# what is your class? sleep
# happy class

# %% [markdown]
# ### BMI Calculator with Interpretations
# Add some if/elif/else statements to the BMI calculator so that it interprets the BMI values calculated.
# If the bmi is under 18.5 (not including), print out "underweight"
# If the bmi is between 18.5 (including) and 25 (not including), print out "normal weight"
# If the bmi is 25 (including) or over, print out "overweight"
# Refer to this graphic for help:

# %%
weight = 85
height = 1.85

bmi = weight / (height ** 2)

if bmi >= 25:
    print("overweight")
elif bmi >= 18.5:
    print("normal weight")
else:
    print("underweight")
# Out:
# normal weight

# %%
print("Welcome to the class")
age = int(input("what is your age :"))

if age >= 20:
    course = input("what is your class?")
    
    if course == "sql":
        fee = 100
    elif course == "python":
        fee = 200
    else:
        fee = 80
        
        certification = input("do you need any certificate? yes/no ")
        
        if certification == "yes":
            fee += 20
        print("Total fee is:", fee)
else:
    print("underage")
# Out:
# Welcome to the class
# what is your age : 25
# what is your class? sleep
# do you need any certificate? yes/no  yes
# Total fee is: 100

# %% [markdown]
# “Python Pizza Deliveries”
# Ask the user what size pizza they want: S, M, or L
# Ask if they want pepperoni (Y or N)
# Ask if they want extra cheese (Y or N)
# Calculate the total bill based on:
# A base price depending on the pizza size
# An additional charge if they want pepperoni (amount may vary by size)
# An additional charge if they want extra cheese
# Print the final total amount they need to pay.

# %% [markdown]
# ### “Python Pizza Deliveries” project) asks you to:
# ###### Ask the user what size pizza they want: S, M, or L
# ###### Ask if they want pepperoni (Y or N)
# ###### Ask if they want extra cheese (Y or N)
# ###### Calculate the total bill based on:
# ###### A base price depending on the pizza size
# ###### An additional charge if they want pepperoni (amount may vary by size)
# ###### An additional charge if they want extra cheese
# ###### Print the final total amount they need to pay.

# %%
print("hi from pizza delivery")
size = input("what is the size of pizza you want S, M, or L")
pepperoni = input("yes or no")
cheese = input("yes or no")
price = 0
if size == 'S':
    price += 15
elif size == 'M':
    price += 20
elif size == 'L':
    price += 25
if pepperoni == "yes":
    if size == "S":
        price += 5
    else:
        price +=10
if cheese == "yes":
            price += 5
print(f"your total bill is  {price}")
# Out:
# hi from pizza delivery
# what is the size of pizza you want S, M, or L L
# yes or no yes
# yes or no yes
# your total bill is  40

# %% [markdown]
# # Python Programming Question: Treasure Island Game
# Write a Python program that creates a simple text-based adventure game called **"Treasure Island."**
# ## Objective:
# The player's mission is to find the treasure.
# ## Instructions:
# 1. Display the following message:
# Welcome to Treasure Island.
# Your mission is to find the treasure.
# 2. Ask the user:
# left or right?
# * If the user types "left", continue the game.
# * If the user types "right" or anything else, print:
# Fall into a hole.
# Game Over.
# 3. If the user chose "left", ask:
# swim or wait?
# * If the user types "wait", continue the game.
# * If the user types "swim" or anything else, print:
# Attacked by trout.
# Game Over.
# 4. If the user chose "wait", ask:
# Which door? Blue, Yellow, or Red?
# * If the user types "Yellow", print:
# You Win!
# * If the user types "Blue", print:
# Eaten by beasts.
# Game Over.
# * If the user types "Red", print:
# Burned by fire.
# Game Over.
# * If the user types anything else, print:
# Game Over.
# ## Requirements:
# * Use if, elif, and else statements.
# * Use input() to get user responses.
# * The program should end immediately when a Game Over condition occurs.

# %%
print("Welcome to Treasure Island. Your mission is to find the treasure.")
turn = input("left or right: ")
if turn == "left":
    play = input("swim or wait: ")
    if play == "wait":
        color = input("blue or red or yellow: ")
        if color == "yellow":
            print("You Win!")
        elif color == "blue":
            print("Eaten by beasts. Game Over.")
        elif color == "red":
            print("Burned by fire. Game Over.")
        else:
            print("Game Over")
            
    else:
        print("Attacked by trout. Game Over.")
        
else:
    print("Fall into a hole. Game Over.")
print('''
____________________________________________________________________
 / \-----     ---------  -----------     -------------- ------    ----\
 \_/__________________________________________________________________/
 |~ ~~ ~~~ ~ ~ ~~~ ~ _____.----------._ ~~~  ~~~~ ~~   ~~  ~~~~~ ~~~~|
 |  _   ~~ ~~ __,---'_       "         `. ~~~ _,--.  ~~~~ __,---.  ~~|
 | | \___ ~~ /      ( )   "          "   `-.,' (') \~~ ~ (  / _\ \~~ |
 |  \    \__/_   __(( _)_      (    "   "     (_\_) \___~ `-.___,'  ~|
 |~~ \     (  )_(__)_|( ))  "   ))          "   |    "  \ ~~ ~~~ _ ~~|
 |  ~ \__ (( _( (  ))  ) _)    ((     \\//    " |   "    \_____,' | ~|
 |~~ ~   \  ( ))(_)(_)_)|  "    ))    //\\ " __,---._  "  "   "  /~~~|
 |    ~~~ |(_ _)| | |   |   "  (   "      ,-'~~~ ~~~ `-.   ___  /~ ~ |
 | ~~     |  |  |   |   _,--- ,--. _  "  (~~  ~~~~  ~~~ ) /___\ \~~ ~|
 |  ~ ~~ /   |      _,----._,'`--'\.`-._  `._~~_~__~_,-'  |H__|  \ ~~|
 |~~    / "     _,-' / `\ ,' / _'  \`.---.._          __        " \~ |
 | ~~~ / /   .-' , / ' _,'_  -  _ '- _`._ `.`-._    _/- `--.   " " \~|
 |  ~ / / _-- `---,~.-' __   --  _,---.  `-._   _,-'- / ` \ \_   " |~|
 | ~ | | -- _    /~/  `-_- _  _,' '  \ \_`-._,-'  / --   \  - \_   / |
 |~~ | \ -      /~~| "     ,-'_ /-  `_ ._`._`-...._____...._,--'  /~~|
 | ~~\  \_ /   /~~/    ___  `---  ---  - - ' ,--.     ___        |~ ~|
 |~   \      ,'~~|  " (o o)   "         " " |~~~ \_,-' ~ `.     ,'~~ |
 | ~~ ~|__,-'~~~~~\    \"/      "  "   "    /~ ~~   O ~ ~~`-.__/~ ~~~|
 |~~~ ~~~  ~~~~~~~~`.______________________/ ~~~    |   ~~~ ~~ ~ ~~~~|
 |____~jrei~__~_______~~_~____~~_____~~___~_~~___~\_|_/ ~_____~___~__|
 / \----- ----- ------------  ------- ----- -------  --------  -------\
 \_/__________________________________________________________________/
''')
# Out:
# Welcome to Treasure Island. Your mission is to find the treasure.
# <>:23: SyntaxWarning: invalid escape sequence '\-'
# <>:23: SyntaxWarning: invalid escape sequence '\-'
# /var/folders/7z/bscj99s54blbjplkwr274whm0000gp/T/ipykernel_51054/278615972.py:23: SyntaxWarning: invalid escape sequence '\-'
#   / \-----     ---------  -----------     -------------- ------    ----\
# left or right:  left
# swim or wait:  swim
# Attacked by trout. Game Over.
#
# ____________________________________________________________________
#  / \-----     ---------  -----------     -------------- ------    ---- \_/__________________________________________________________________/
#  |~ ~~ ~~~ ~ ~ ~~~ ~ _____.----------._ ~~~  ~~~~ ~~   ~~  ~~~~~ ~~~~|
#  |  _   ~~ ~~ __,---'_       "         `. ~~~ _,--.  ~~~~ __,---.  ~~|
#  | | \___ ~~ /      ( )   "          "   `-.,' (') \~~ ~ (  / _\ \~~ |
#  |  \    \__/_   __(( _)_      (    "   "     (_\_) \___~ `-.___,'  ~|
# ...
